# %%
# %matplotlib inline

import h5py, os
import numpy as np
from matplotlib import pyplot as plt

# %%
file_path = 'C:/Users/just4/Onedrive/Documents/NC2019MRI/train/'

for fname in sorted(os.listdir(file_path)):
    subject_path = os.path.join(file_path, fname)
    with h5py.File(subject_path, "a") as hf:
        print(f'file {fname} key is {list(hf.keys())}')
# Out:
# file file1000000.h5 key is ['kspace']
# file file1000007.h5 key is ['kspace']
# file file1000017.h5 key is ['kspace']
# file file1000026.h5 key is ['kspace']
# file file1000031.h5 key is ['kspace']
# file file1000033.h5 key is ['kspace']
# file file1000041.h5 key is ['kspace']
# file file1000052.h5 key is ['kspace']
# file file1000071.h5 key is ['kspace']
# file file1000073.h5 key is ['kspace']
# file file1000107.h5 key is ['kspace']
# file file1000108.h5 key is ['kspace']
# file file1000114.h5 key is ['kspace']
# file file1000126.h5 key is ['kspace']
# file file1000153.h5 key is ['kspace']
# file file1000178.h5 key is ['kspace']
# file file1000182.h5 key is ['kspace']
# file file1000190.h5 key is ['kspace']
# file file1000196.h5 key is ['kspace']
# file file1000201.h5 key is ['kspace']
# file file1000206.h5 key is ['kspace']
# file file1000229.h5 key is ['kspace']
# file file1000243.h5 key is ['kspace']
# file file1000247.h5 key is ['kspace']
# file file1000254.h5 key is ['kspace']
# ...

# %%
file_path = 'C:/Users/just4/Onedrive/Documents/NC2019MRI/train/file1000000.h5'

with h5py.File(file_path,  "r") as hf:      # Read-only
    volume_kspace = hf['kspace'][()]
    print(volume_kspace.shape)
    print(volume_kspace.dtype)
# Out:
# (35, 640, 368)
# complex64

# %% [markdown]
# k-space is complex-valued and has the following shape: (number of slices, height, width).

# %%
def show_slices(data, slice_nums, cmap=None):
    fig = plt.figure(figsize=(15,10))
    for i, num in enumerate(slice_nums):
        plt.subplot(1, len(slice_nums), i + 1)
        plt.imshow(data[num], cmap=cmap)
        plt.axis('off')

# %%
volume_kspace.sum()
# Out:
# (0.5325656-0.006377424j)

# %%
volume_kspace.nonzero()
# Out:
# (array([ 0,  0,  0, ..., 34, 34, 34], dtype=int64),
#  array([  0,   0,   0, ..., 639, 639, 639], dtype=int64),
#  array([ 18,  19,  20, ..., 347, 348, 349], dtype=int64))

# %%
show_slices(np.log(np.abs(volume_kspace) + 1e-9), [5, 10, 20, 30], cmap='gray')

# %%
from functions import transforms as T
